# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
videogames = pd.read_csv("vgsales.csv")

# %%
videogames
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
videogames["Platform"].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
videogames["EU_Sales"]
# Out:
# 0        29.02
# 1         3.58
# 2        12.88
# 3        11.01
# 4         8.89
#          ...
# 16593     0.00
# 16594     0.00
# 16595     0.00
# 16596     0.01
# 16597     0.00
# Name: EU_Sales, Length: 16598, dtype: float64

# %%
videogames.groupby("Platform")["Global_Sales"].agg(["mean", "median"])
# Out:
#               mean  median
# Platform
# 2600      0.729925   0.460
# 3DO       0.033333   0.020
# 3DS       0.486169   0.120
# DC        0.307115   0.135
# DS        0.380254   0.110
# GB        2.606633   1.165
# GBA       0.387470   0.165
# GC        0.358561   0.150
# GEN       1.050370   0.150
# GG        0.040000   0.040
# N64       0.686144   0.270
# NES       2.561939   1.375
# NG        0.120000   0.100
# PC        0.269604   0.040
# PCFX      0.030000   0.030
# PS        0.610920   0.260
# PS2       0.581046   0.230
# PS3       0.720722   0.280
# PS4       0.827679   0.220
# PSP       0.244254   0.090
# PSV       0.149952   0.060
# SAT       0.194162   0.120
# SCD       0.311667   0.065
# SNES      0.837029   0.320
# TG16      0.080000   0.080
# WS        0.236667   0.215
# Wii       0.699404   0.200
# WiiU      0.572448   0.230
# X360      0.774672   0.280
# XB        0.313422   0.140
# XOne      0.662254   0.240

# %%
eixo_x = videogames["Genre"].value_counts().keys()
eixo_y = videogames["Genre"].value_counts().values

# %%
plt.bar(eixo_x, eixo_y)

plt.title("Games por generos")

plt.xticks(rotation=45)

plt.xlabel("Gêneros de jogos")
plt.ylabel("Quantidade de jogos")

plt.show()

# %%
videogames
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
eixo_x = videogames["Year"].value_counts().sort_index().keys()
eixo_y = videogames["Year"].value_counts().sort_index().values

# %%
plt.plot(eixo_x,eixo_y)
plt.show()

# %%
videogames
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
def mudar(linha):
    if linha["Genre"] == "Sports":
        linha["Genre"] = "Esporte"
    return linha

# %%
videogames.apply(lambda x: mudar(x), axis=1)
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
videogames
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...
